# %%
#журнал посещения студентов группы АСУ-4
class student_magizine:
    def __init__(self, date, student1, student2, student3, student4,  student5,  student6, student7, student8):
        self.date = date
        self.student1 = student1
        self.student2 = student2
        self.student3 = student3
        self.student4 = student4
        self.student5 = student5
        self.student6 = student6
        self.student7 = student7
        self.student8 = student8

    def setting_date(self, date):
        self.date = date
        print('Дата посещения ', date, 'успешно установлена')

    def setting_student1(self, student1):
        self.student1 = student1
        print('Посещение студента 1 изменено', student1)
        print('')

    def setting_student2(self, student2):
        self.student2 = student2
        print('Посещение студента 2 изменено', student2)
        print('')

    def setting_student3(self, student3):
        self.student3 = student3
        print('Посещение студента 3 изменено', student3)
        print('')

    def setting_student4(self, student4):
        self.student4 = student4
        print('Посещение студента 4 изменено', student4)
        print('')

    def setting_student5(self, student5):
        self.student5 = student5
        print('Посещение студента 5 изменено', student5)
        print('')

    def setting_student6(self, student6):
        self.student6 = student6
        print('Посещение студента 6 изменено', student6)
        print('')

    def setting_student7(self, student7):
        self.student7 = student7
        print('Посещение студента 7 изменено', student7)
        print('')

    def setting_student8(self, student8):
        self.student8 = student8
        print('Посещение студента 8 изменено', student8)
        print('')

def show_attendance_students(self): #вывод посещаемости студентов в данный день
        print('Посещаемость студентов на ', self.date)
        print('Cтудент1:', self.student1)
        print('Cтудент2:', self.student2)
        print('Cтудент3:', self.student3)
        print('Cтудент4:', self.student4)
        print('Cтудент5:', self.student5)
        print('Cтудент6:', self.student6)
        print('Cтудент7:', self.student7)
        print('Cтудент8:', self.student8)
        print('')

    #Заполнение посещаемости
D1 = student_magizine('01.01.2022', 'Посещал', 'Посещал', 'Посещал', 'Посещал', 'Посещал', 'Посещал', 'Посещал', 'Посещал')
D2 = student_magizine('07.01.2022', 'Посещал', 'Отсуствовал', 'Посещал', 'Отсуствовал', 'Посещал', 'Посещал', 'Отсуствовал', 'Посещал')
D3 = student_magizine('14.01.2022', 'Отсуствовал', 'Посещал', 'Отсуствовал', 'Отсуствовал', 'Посещал', 'Посещал', 'Посещал', 'Отсуствовал')
D4 = student_magizine('21.01.2022', 'Отсуствовал', 'Отсуствовал', 'Отсуствовал', 'Посещал', 'Посещал', 'Посещал', 'Посещал', 'Посещал')

    #Вывод посещаемости
show_attendance_students(D1)
show_attendance_students(D2)
show_attendance_students(D3)
show_attendance_students(D4)

    #Изменение посещаемости
D1.setting_student8('Отсуствовал')
D1.setting_student4('Отсуствовал')
D2.setting_student2('Посещал')
D2.setting_date('08.01.2022')

show_attendance_students(D1)
show_attendance_students(D2)
